# %% [markdown]
# Creating Network Graph in VizTool

# %%
#마스터 테이블 : 사용자가 연결한 컴포넌트, 연결고리 정보 with version 테이블 생성 및 업데이트

# %%
# network graph 테이블 -> 위 테이블의 결과로 생성되는 테이블

# %% [markdown]
# RDB to GraphDB Tranformation

# %%
#schema 생성

# %%
# cypher template 생성 -> 실제 데이터를 graphDB로 변환하는 과정

# %% [markdown]
# GraphDB to RDB Transformation

# %%
# 스키마 단의 노드들을 컬럼들로 변환, 각 노드 값들을 행으로 변환하여 저장
# ## 테이블은 하나로 통합, 추후 분리 가능하도록 설계

# %%
# 마스터 테이블 역시 저장해야할듯?
