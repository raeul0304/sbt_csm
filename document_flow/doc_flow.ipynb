# %%
import psycopg
from psycopg import sql
import importlib
import config
importlib.reload(config)
import pandas as pd
from typing import List, Dict, Any
from datetime import datetime

# %% [markdown]
# DB 연결

# %%
def get_db_connection():
    try:
        conn = psycopg.connect(
            dbname=config.DB_NAME,
            user=config.DB_USER,
            password=config.DB_PASSWORD,
            host=config.DB_HOST,
            port=config.DB_PORT
        )
        print("데이터베이스에 성공적으로 연결되었습니다.")
        return conn
    except Exception as e:
        print(f"데이터베이스 연결 실패: {e}")
        return None

# %% [markdown]
# 전체 경로 조회

# %%
def get_document_flow_path(sales_order_number, connection):
   
    if not connection:
        return []
        
    print(f"1단계: VBFA 테이블에서 Document Flow 경로를 조회 중입니다... (Sales Order: {sales_order_number})")
    
    query = """
    SELECT
        VBELV AS pre_doc_no,
        VBELN AS post_doc_no,
        VBTYP_V AS pre_doc_type,
        VBTYP_N AS post_doc_type
    FROM
        VBFA
    WHERE
        (VBELV = LPAD(%s, 10, '0') AND VBTYP_N = 'J')
        OR VBELV IN (
            SELECT VBELN
            FROM VBFA
            WHERE VBELV = LPAD(%s, 10, '0') AND VBTYP_N = 'J'
        )
    ORDER BY
        ERDAT,
        ERZET;
    """
    
    try:
        cursor = connection.cursor()
        cursor.execute(query, (sales_order_number, sales_order_number))
        columns = [c.name if hasattr(c, "name") else c[0] for c in cursor.description]
        path_results = [dict(zip(columns, row)) for row in cursor.fetchall()]
        return path_results
    except Exception as e:
        print(f"쿼리 실행 중 오류 발생: {e}")
        return []

# %% [markdown]
# 실행 (전체 경로 조회)

# %%
sales_no = input(int())
conn = get_db_connection()
doc_path = get_document_flow_path(sales_no, conn)
pd.DataFrame(doc_path)
# Out:
# 데이터베이스에 성공적으로 연결되었습니다.
# 1단계: VBFA 테이블에서 Document Flow 경로를 조회 중입니다... (Sales Order: 21)
#    pre_doc_no post_doc_no pre_doc_type post_doc_type
# 0  0000000021  0080000019            C             J
# 1  0080000019    20240423            J             Q
# 2  0080000019  4900000219            J             R
# 3  0080000019  0090000024            J             M
# 4  0080000019  0090000025            J             N
# 5  0080000019  4900000225            J             h
# 6  0080000019  4900000226            J             R
# 7  0080000019  0090000026            J             M

# %% [markdown]
# document별 데이터 출력

# %%
def execute_sql(conn, sql, params=None):
    if conn is None:
        raise ValueError("연결된 DB가 없습니다 (conn is None).")

    try:
        with conn.cursor() as cur:
            if params is not None:
                cur.execute(sql, params)
            else:
                cur.execute(sql)

            rows = cur.fetchall()
            cols = [desc[0] for desc in cur.description] if cur.description else []
            return pd.DataFrame(rows, columns=cols)
    except Exception as e:
        conn.rollback()
        print("SQL 실패:\n", sql)
        print("params:", params)
        raise e

# %%
def get_sales_order_details(conn, sales_order_number):
    """Sales Order 상세 데이터를 조회"""
    #print(f" - Sales Order ({sales_order_number}) 조회 중...")
    query = """
    SELECT
      'Sales Order' AS document_type,
      VBAK.VBELN AS doc_no,
      VBAP.POSNR AS item,
      VBAP.VGBEL AS preced_doc,
      VBAP.VGPOS AS orig_item,
      VBAP.KWMENG AS quantity,
      VBAP.VRKME AS unit,
      VBAP.NETWR AS ref_value,
      VBAK.WAERK AS curr,
      VBAK.ERDAT AS created_on,
      VBAP.MATNR AS material,
      VBAP.ARKTX AS description,
      CASE
        WHEN VBAK.GBSTK='C' THEN 'Completed'
        WHEN VBAK.GBSTK='B' THEN 'Partially Completed'
        WHEN VBAK.GBSTK='A' THEN 'Not Completed'
        ELSE 'Unknown'
      END AS status,
      'C' AS doc_code
    FROM VBAK
    JOIN VBAP ON VBAK.VBELN = VBAP.VBELN
    WHERE VBAK.VBELN = LPAD(%s, 10, '0')
    """
    return execute_sql(conn, query, (sales_order_number,))


def get_outbound_delivery_details(conn, doc_no, pre_doc_no=None):
    """Outbound Delivery (J) 상세 데이터를 조회"""
    #print(f" - Outbound Delivery ({doc_no}) 조회 중...")
    query = """ 
    SELECT
      'Outbound Delivery' AS document_type,
      LIKP.VBELN AS doc_no,
      LIPS.POSNR AS item,
      LIPS.VGBEL AS preced_doc,
      LIPS.VGPOS AS orig_item,
      LIPS.LFIMG AS quantity,
      LIPS.VRKME AS unit,
      LIKP.ERDAT AS created_on,
      LIPS.MATNR AS material,
      LIPS.ARKTX AS description,
      CASE
        WHEN LIKP.GBSTK='C' THEN 'Completed'
        WHEN LIKP.GBSTK='B' THEN 'Partially Completed'
        WHEN LIKP.GBSTK='A' THEN 'Not Completed'
        ELSE 'Unknown'
      END AS status,
      'J' AS doc_code
    FROM LIKP
    JOIN LIPS ON LIKP.VBELN = LIPS.VBELN
    WHERE LIKP.VBELN = %s
    """
    return execute_sql(conn, query, (doc_no,))


def get_picking_request_details(conn, doc_no, pre_doc_no):
    """Picking Request (Q) 상세 데이터를 조회"""
    #print(f" - Picking Request ({doc_no}) 조회 중...")
    date_obj = datetime.strptime(doc_no, '%Y%m%d')
    formatted_doc_no = date_obj.strftime('%Y-%m-%d')
    #print(f"Formatted Picking Request No: {formatted_doc_no}")
    query = """ 
    SELECT
      'Picking Request' AS document_type,
      LIKP.ERDAT AS doc_no,
      LIPS.POSNR AS item,
      LIKP.VBELN AS preced_doc,
      LIPS.VGPOS AS orig_item,
      LIPS.LFIMG AS quantity,
      LIPS.VRKME AS unit,
      LIKP.ERDAT AS created_on,
      LIPS.MATNR AS material,
      LIPS.ARKTX AS description,
      CASE
        WHEN LIKP.GBSTK='C' THEN 'Completed'
        WHEN LIKP.GBSTK='B' THEN 'Partially Completed'
        WHEN LIKP.GBSTK='A' THEN 'Not Completed'
        ELSE 'Unknown'
      END AS status,
      'Q' AS doc_code
    FROM LIKP
    JOIN LIPS ON LIKP.VBELN = LIPS.VBELN
    WHERE LIKP.ERDAT = %s AND LIKP.VBELN = %s
    """
    result = execute_sql(conn, query, (formatted_doc_no, pre_doc_no,))
    result['doc_no'] = result['doc_no'].astype(str).str.replace('-', '', regex=False)
    return result


def get_goods_issue_details(conn, doc_no, pre_doc_no=None):
    """GD Goods Issue (R) 상세 데이터를 조회"""
    #print(f" - GD Goods Issue ({doc_no}) 조회 중...")
    query = """
    SELECT
      'GD Goods Issue' AS document_type,
      MSEG.MBLNR AS doc_no,
      MSEG.ZEILE AS item,
      MSEG.VBELN_IM AS preced_doc,
      MSEG.VBELP_IM AS orig_item,
      MSEG.MENGE AS quantity,
      MSEG.MEINS AS unit,
      MSEG.DMBTR AS ref_value,
      MSEG.WAERS AS curr,
      MSEG.CPUDT_MKPF AS created_on,
      MSEG.MATNR AS material,
      LIPS.ARKTX AS description,
      CASE
        WHEN LIKP.WBSTK='C' THEN 'Completed'
        WHEN LIKP.WBSTK='B' THEN 'Partially Completed'
        WHEN LIKP.WBSTK='A' THEN 'Not Completed'
        ELSE 'Unknown'
      END AS status,
      'R' AS doc_code
    FROM MSEG
    LEFT JOIN LIPS ON MSEG.VBELN_IM = LIPS.VBELN AND MSEG.VBELP_IM = LIPS.POSNR
    LEFT JOIN LIKP ON LIPS.VBELN = LIKP.VBELN
    WHERE MSEG.MBLNR = %s
"""
    return execute_sql(conn, query, (doc_no,))


def get_re_goods_delivery_details(conn, doc_no, pre_doc_no=None):
    """RE goods delivery (h) 상세 데이터를 조회"""
    #print(f" - RE goods delivery ({doc_no}) 조회 중...")
    query = """
    SELECT
      'RE Goods Delivery' AS document_type,
      MSEG.MBLNR AS doc_no,
      MSEG.ZEILE AS item,
      MSEG.VBELN_IM AS preced_doc,
      MSEG.VBELP_IM AS orig_item,
      MSEG.MENGE AS quantity,
      MSEG.MEINS AS unit,
      MSEG.DMBTR AS ref_value,
      MSEG.WAERS AS curr,
      MSEG.CPUDT_MKPF AS created_on,
      MSEG.MATNR AS material,
      LIPS.ARKTX AS description,
      CASE
        WHEN LIKP.GBSTK='C' THEN 'Completed'
        WHEN LIKP.GBSTK='B' THEN 'Partially Completed'
        WHEN LIKP.GBSTK='A' THEN 'Not Completed'
        ELSE 'Unknown'
      END AS status,
      'h' AS doc_code
    FROM MSEG
    LEFT JOIN LIPS ON MSEG.VBELN_IM = LIPS.VBELN AND MSEG.VBELP_IM = LIPS.POSNR
    LEFT JOIN LIKP ON LIPS.VBELN = LIKP.VBELN
    WHERE MSEG.MBLNR = %s
    """
    return execute_sql(conn, query, (doc_no,))


def get_invoice_details(conn, doc_no, pre_doc_no=None):
    """Invoice (M) 상세 데이터를 조회"""
    #print(f" - Invoice ({doc_no}) 조회 중...")
    query = """
    SELECT
        'Invoice' AS document_type,
        VBRK.VBELN AS doc_no,
        VBRP.POSNR AS item,
        VBRP.VGBEL AS preced_doc,
        VBRP.VGPOS AS orig_item,
        VBRP.FKIMG AS quantity,
        VBRP.VRKME AS unit,
        VBRP.NETWR AS ref_value,
        VBRK.WAERK AS curr,
        VBRK.ERDAT AS created_on,
        VBRP.MATNR AS material,
        VBRP.ARKTX AS description,
        CASE
            WHEN VBRK.GBSTK='C' THEN 'Completed'
            WHEN VBRK.GBSTK='B' THEN 'Partially Completed'
            WHEN VBRK.GBSTK='A' THEN 'Not Completed'
            ELSE 'Unknown'
        END AS status,
        'M' as doc_code
    FROM VBRK
    JOIN VBRP ON VBRK.VBELN = VBRP.VBELN
    WHERE VBRK.VBELN = %s
    """
    return execute_sql(conn, query, (doc_no,))


def get_cancel_invoice_details(conn, doc_no, pre_doc_no=None):
    """Cancel Invoice (N) 상세 데이터를 조회"""
    #print(f" - Cancel Invoice ({doc_no}) 조회 중...")
    query = """
    SELECT
      'Cancel Invoice' AS document_type,
      VBRK.VBELN AS doc_no,         
      VBRP.POSNR AS item,          
      VBRK.STBLG AS preced_doc,    
      VBRP.VGPOS AS orig_item,    
      VBRP.FKIMG AS quantity,   
      VBRP.VRKME AS unit,     
      VBRP.NETWR AS ref_value,     
      VBRK.WAERK AS curr,         
      VBRK.ERDAT AS created_on,   
      VBRP.MATNR AS material,       
      VBRP.ARKTX AS description,  
      CASE
        WHEN VBRK.GBSTK='C' THEN 'Completed'
        WHEN VBRK.GBSTK='B' THEN 'Partially Completed'
        WHEN VBRK.GBSTK='A' THEN 'Not Completed'
        ELSE 'Unknown'
      END AS status,
      'N' AS doc_code          
    FROM VBRK
    JOIN VBRP ON VBRP.VBELN = VBRK.VBELN
    WHERE VBRK.VBELN = %s
    """
    return execute_sql(conn, query, (doc_no,))
  

def get_journal_entry_details(conn, doc_no):
    """Cancel Invoice - Journal Entry 상세 데이터를 조회"""
    #print(f" - Journal Entry ({doc_no}) 조회 중...")
    query = """
    SELECT
      'Journal Entry' AS document_type,
      BSEG.BELNR AS doc_no,
      BSEG.VBELN as preced_doc,
      BSEG.WRBTR AS ref_value,
      BKPF.WAERS AS curr,
      BKPF.CPUDT AS created_on,
      CASE 
        WHEN BSEG.AUGBL IS NULL OR TRIM(BSEG.AUGBL) = '' 
        THEN 'Not Cleared' 
        ELSE 'Cleared' 
      END AS status,
      'E' AS doc_code
    FROM BSEG
    JOIN BKPF ON BKPF.BELNR = BSEG.BELNR
    WHERE BSEG.VBELN = %s AND BSEG.KOART = 'D'
    """
    return execute_sql(conn, query, (doc_no,))

# %%
conn = get_db_connection()
# Out:
# 데이터베이스에 성공적으로 연결되었습니다.

# %%
# get_cancel_invoice_details(conn, '0090000024', '0080000019')

# %%
def get_document_details(sales_order_number, document_path, conn):
    """
    Document Flow 경로 목록을 기반으로 각 문서의 상세 데이터를 조회하는 함수.
    """
    final_data = []
    delivery_doc_no = None

    # Sales Order 상세 데이터 조회 (경로와 관계없이 항상 조회)
    so_df = get_sales_order_details(conn, sales_order_number)
    if not so_df.empty:
        #print(f"sales order 결과: {pd.DataFrame(so_df)}")
        final_data.append(so_df)

    print("2단계: 경로에 따라 후속 문서 상세 데이터 조회 중...")

    # 1) document_path가 DataFrame이면 row dict 리스트로 변환
    if isinstance(document_path, pd.DataFrame):
        rows = document_path.to_dict(orient='records')
    else:
        rows = document_path

    # 2) 각 row에서 post 문서만 추출하여 조회
    for row in rows:
        doc_no   = row.get('post_doc_no')
        doc_type = row.get('post_doc_type')
        result = pd.DataFrame() # 결과 초기화
        
        if doc_type == 'J':
            result = get_outbound_delivery_details(conn, doc_no)
            final_data.append(result)  
            #print(f"outbound delivery 결과: {pd.DataFrame(result)}")
            delivery_doc_no = result['doc_no'].iloc[0]
            #print(f"Delivery Doc No: {delivery_doc_no}")
        
        elif doc_type == 'Q':
            result = get_picking_request_details(conn, doc_no, pre_doc_no=delivery_doc_no)
            final_data.append(result)  
            #print(f"picking request 결과: {result}")
            
        
        elif doc_type == 'R':
            result = get_goods_issue_details(conn, doc_no, pre_doc_no=delivery_doc_no)
            final_data.append(result)  
            #print(f"goods issue 결과: {result}")

        
        elif doc_type == 'h':
            result = get_re_goods_delivery_details(conn, doc_no, pre_doc_no=delivery_doc_no)
            final_data.append(result)  
            #print(f"RE goods delivery 결과: {result}")


        elif doc_type == 'M':
            result = get_invoice_details(conn, doc_no, pre_doc_no=delivery_doc_no)
            #print(f"invoice 결과: {result}")
            final_data.append(result)  
            invoice_doc_no = result['doc_no'].iloc[0]

            journal_result = get_journal_entry_details(conn, invoice_doc_no)
            if journal_result is not None:
                #print(f"journal entry 결과: {journal_result}")
                final_data.append(journal_result)
        
        elif doc_type == 'N':
            result = get_cancel_invoice_details(conn, doc_no, pre_doc_no=delivery_doc_no)
            #print(f"cancel invoice 결과: {result}")
            final_data.append(result)  
            cancel_invoice_doc_no = result['doc_no'].iloc[0]

            journal_result = get_journal_entry_details(conn, cancel_invoice_doc_no)
            if journal_result is not None:
                #print(f"journal entry 결과: {journal_result}")
                final_data.append(journal_result)
     

    if final_data:
        return pd.concat(final_data, ignore_index=True)
    return pd.DataFrame()

# %% [markdown]
# 실행

# %%
def run_documentflow_pipeline(sales_no):
    conn = get_db_connection()
    if conn:
        doc_path = get_document_flow_path(sales_no, conn)
        
        if not doc_path:
            sales_doc = get_sales_order_details(conn, sales_no)
            if sales_doc.empty:
                print(f"\nDocument Flow가 없습니다. (Sales Order: {sales_no})")
                return None
            print("\n최종결과:")
            print(pd.DataFrame(sales_doc))

        else:
            print("\n성공적으로 Document Flow 경로를 조회했습니다.")
            print(pd.DataFrame(doc_path))
            
            final_result = get_document_details(sales_no, doc_path, conn)
            
            print("\n최종결과:")
            #print(pd.DataFrame(final_result))
            return final_result
        
        conn.close()
    else:
        print("프로그램을 종료합니다.")

# %%
sales_no = input("조회할 Sales Order 번호를 입력하세요: ")
final_df = run_documentflow_pipeline(sales_no)
final_df
# Out:
# 데이터베이스에 성공적으로 연결되었습니다.
# 1단계: VBFA 테이블에서 Document Flow 경로를 조회 중입니다... (Sales Order: 21)
#
# 성공적으로 Document Flow 경로를 조회했습니다.
#    pre_doc_no post_doc_no pre_doc_type post_doc_type
# 0  0000000021  0080000019            C             J
# 1  0080000019    20240423            J             Q
# 2  0080000019  4900000219            J             R
# 3  0080000019  0090000024            J             M
# 4  0080000019  0090000025            J             N
# 5  0080000019  4900000225            J             h
# 6  0080000019  4900000226            J             R
# 7  0080000019  0090000026            J             M
# 2단계: 경로에 따라 후속 문서 상세 데이터 조회 중...
#
# 최종결과:
#         document_type      doc_no item  preced_doc orig_item quantity unit  \
# 0         Sales Order  0000000021   10                     0       10   EA
# 1   Outbound Delivery  0080000019   10  0000000021        10       10   EA
# 2     Picking Request    20240423   10  0080000019        10       10   EA
# 3      GD Goods Issue  4900000219    1  0080000019        10       10   EA
# 4             Invoice  0090000024   10  0080000019        10       10   EA
# 5       Journal Entry  0090000024  NaN  0090000024       NaN      NaN  NaN
# 6      Cancel Invoice  0090000025   10        None        10       10   EA
# 7       Journal Entry  0100000330  NaN  0090000025       NaN      NaN  NaN
# 8   RE Goods Delivery  4900000225    1  0080000019        10       10   EA
# 9      GD Goods Issue  4900000226    1  0080000019        10       10   EA
# 10            Invoice  0090000026   10  0080000019        10       10   EA
# 11      Journal Entry  0090000026  NaN  0090000026       NaN      NaN  NaN
#
#        ref_value curr  created_on material description       status doc_code
# 0      250000000  KRW  2024-04-23  FERT301        KONA    Completed        C
# 1            NaN  NaN  2024-04-23  FERT301        KONA    Completed        J
# 2            NaN  NaN  2024-04-23  FERT301        KONA    Completed        Q
# 3      199095990  KRW  2024-04-23  FERT301        KONA    Completed        R
# 4   2,500,000,00  KRW  2024-04-23  FERT301        KONA    Completed        M
# 5   2,500,000,00  KRW  2024-04-23      NaN         NaN      Cleared        E
# 6   2,500,000,00  KRW  2024-04-24  FERT301        KONA    Completed        N
# 7   2,500,000,00  KRW  2024-04-24      NaN         NaN      Cleared        E
# 8      199095990  KRW  2024-04-24  FERT301        KONA    Completed        h
# 9      199095990  KRW  2024-04-24  FERT301        KONA    Completed        R
# 10  2,500,000,00  KRW  2024-04-24  FERT301        KONA    Completed        M
# 11  2,500,000,00  KRW  2024-04-24      NaN         NaN  Not Cleared        E

# %% [markdown]
# 전체 결과 json 형태 변환 - along with edges information

# %%
#group 정의
SALES_ORDER = ['Sales Order']
DELIVERY = ['Outbound Delivery', 'Picking Request', 'GD Goods Issue', 'RE Goods Delivery']
BILLING = ['Invoice', 'Cancel Invoice']
ACCOUNTING = ['Journal Entry']

# %%
X_BY_GROUP = {
    "SALES_ORDER": 0,
    "DELIVERY": 150,
    "BILLING": 300,
    "ACCOUNTING": 450,
}
Y_GAP = 150

# %%
RULES: Dict[str, List[str]] = {
        "J": ["C"],            # Outbound Delivery <- Sales Order
        "Q": ["J"],            # Picking Request <- Outbound Delivery
        "R": ["Q", "h"],       # GD Goods Issue <- Picking Request
        "M": ["R"],            # Invoice <- GD Goods Issue
        "h": ["R"],            # RE Goods Delivery <- GD Goods Issue
        "N": ["M"],            # Cancel Invoice <- Invoice
        "E": ["M", "N"],       # Journal Entry <- Invoice or Cancel Invoice
    }

# %%
def get_group(doc_type: str) -> str:
    if doc_type in SALES_ORDER:  return "SALES_ORDER"
    if doc_type in DELIVERY:     return "DELIVERY"
    if doc_type in BILLING:      return "BILLING"
    if doc_type in ACCOUNTING:   return "ACCOUNTING"
    return "DELIVERY"  # fallback

# %%
# edges 정의
def build_flow_edges(df) -> List[Dict[str, Any]]:
    last_seen_idx : Dict[str, int] = {}
    edges: List[Dict[str, Any]] = []

    for i, row in df.reset_index(drop=True).iterrows():
        cur_code = str(row["doc_code"]).strip()

        if cur_code in RULES:
            candidates = RULES[cur_code]

            best_src = None
            best_idx = -1

            for cand_code in candidates:
                if cand_code in last_seen_idx and last_seen_idx[cand_code] < i:
                    if last_seen_idx[cand_code] > best_idx:
                        best_idx = last_seen_idx[cand_code]
                        best_src = cand_code
            
            if best_src:
                eid = f"{best_src}-{cur_code}-{i}"
                edges.append({
                    "id": eid,
                    "source": f"{best_src}-{best_idx}",
                    "target": f"{cur_code}-{i}",
                    "type": "lrstep",
                    "markerEnd": {"type": "ArrowClosed"}
                })
        
        last_seen_idx[cur_code] = i
    
    return edges

# %%
edges = build_flow_edges(final_df)
edges
# Out:
# [{'id': 'C-J-1',
#   'source': 'C-0',
#   'target': 'J-1',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'J-Q-2',
#   'source': 'J-1',
#   'target': 'Q-2',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'Q-R-3',
#   'source': 'Q-2',
#   'target': 'R-3',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'R-M-4',
#   'source': 'R-3',
#   'target': 'M-4',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'M-E-5',
#   'source': 'M-4',
#   'target': 'E-5',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'M-N-6',
#   'source': 'M-4',
#   'target': 'N-6',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'N-E-7',
#   'source': 'N-6',
#   'target': 'E-7',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'R-h-8',
#   'source': 'R-3',
#   'target': 'h-8',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'h-R-9',
#   'source': 'h-8',
#   'target': 'R-9',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'R-M-10',
#   'source': 'R-9',
#   'target': 'M-10',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}},
#  {'id': 'M-E-11',
#   'source': 'M-10',
#   'target': 'E-11',
#   'type': 'lrstep',
#   'markerEnd': {'type': 'ArrowClosed'}}]

# %%
# position 계산
def compute_positions(df, edges) -> Dict[str, Dict[str, int]]:
    meta: Dict[str, Dict[str, str]] = {}
    
    for i, row in df.iterrows():
        doc_code = str(row["doc_code"]).strip()
        dtype = str(row["document_type"]).strip()
        nid = f"{doc_code}-{i}"
        group = get_group(dtype)
        meta[nid] = {"doc_type": dtype, "doc_code": doc_code, "group": group}
    
    
    latest_y = 0
    position: Dict[str, Dict[str, int]] = {}  #결과 포지션

    #sales order
    for i, row in enumerate(df.itertuples(index=False), start=0):
        if getattr(row, "document_type") in SALES_ORDER:
            so_id = f"{str(getattr(row, 'doc_code')).strip()}-{i}"
            position[so_id] = {"x": X_BY_GROUP["SALES_ORDER"], "y": 0}
            break

    #엣지 순서에 따른 포지션 계산
    for e in edges:
        src, tgt = e["source"], e["target"]
        src_group, tgt_group = meta[src]["group"], meta[tgt]["group"]

        #source 배치 x시 처리
        if src not in position:
            sx = X_BY_GROUP[src_group]
            sy = latest_y
            position[src] = {"x": sx, "y": sy}
        
        #target 배치
        tx = X_BY_GROUP[tgt_group]
        if src_group == tgt_group:
            # 다른 레인이면 최근 y + 150
            latest_y += Y_GAP
            ty = latest_y
        else:
            # 다른 레인이면 source와 같은 y
            ty = position[src]["y"]
        
        position[tgt] = {"x": tx, "y": ty}
    
    #최종 meta 구성
    for nid, p in position.items():
        meta[nid]["position"] = p
    
    return meta

# %%
positions = compute_positions(final_df, edges)
print(positions)
# Out:
# {'C-0': {'doc_type': 'Sales Order', 'doc_code': 'C', 'group': 'SALES_ORDER', 'position': {'x': 0, 'y': 0}}, 'J-1': {'doc_type': 'Outbound Delivery', 'doc_code': 'J', 'group': 'DELIVERY', 'position': {'x': 150, 'y': 0}}, 'Q-2': {'doc_type': 'Picking Request', 'doc_code': 'Q', 'group': 'DELIVERY', 'position': {'x': 150, 'y': 150}}, 'R-3': {'doc_type': 'GD Goods Issue', 'doc_code': 'R', 'group': 'DELIVERY', 'position': {'x': 150, 'y': 300}}, 'M-4': {'doc_type': 'Invoice', 'doc_code': 'M', 'group': 'BILLING', 'position': {'x': 300, 'y': 300}}, 'E-5': {'doc_type': 'Journal Entry', 'doc_code': 'E', 'group': 'ACCOUNTING', 'position': {'x': 450, 'y': 300}}, 'N-6': {'doc_type': 'Cancel Invoice', 'doc_code': 'N', 'group': 'BILLING', 'position': {'x': 300, 'y': 450}}, 'E-7': {'doc_type': 'Journal Entry', 'doc_code': 'E', 'group': 'ACCOUNTING', 'position': {'x': 450, 'y': 450}}, 'h-8': {'doc_type': 'RE Goods Delivery', 'doc_code': 'h', 'group': 'DELIVERY', 'position': {'x': 150, 'y': 600}}, 'R-9': {'doc_type': 'GD Goods Issue', 'doc_code': 'R', 'group': 'DELIVERY', 'position': {'x': 150, 'y': 750}}, 'M-10': {'doc_type': 'Invoice', 'doc_code': 'M', 'group': 'BILLING', 'position': {'x': 300, 'y': 750}}, 'E-11': {'doc_type': 'Journal Entry', 'doc_code': 'E', 'group': 'ACCOUNTING', 'position': {'x': 450, 'y': 750}}}

# %%
#node json 구성
def build_nodes(df, positions):
    nodes = []

    def create_default_node(nid, info):
        return {
            "id": nid,
            "type": "doc_flow",
            "position": info["position"],
            "data": {"label": info["doc_type"]}
        }

    for nid, info in positions.items():
        try:
            parts = nid.split('-') #인덱스 추출
            row_idx = int(parts[-1])

            if row_idx < len(df):
                row = df.iloc[row_idx]
                header = {
                    "status": str(row.get('status', '')),
                    "doc_no": str(row.get('doc_no', '')),
                    "value": str(row.get('ref_value', '')),
                    "time": str(row.get('created_on', ''))
                }

                detail = []
                for col_name, col_value in row.items():
                    detail.append({
                        "name": col_name,
                        "value": str(col_value) if col_value is not None else '',
                        "id": col_name + "_" + nid
                    })
                
                nodes.append({
                    "id": nid,
                    "type" : "doc_flow",
                    "position": info["position"],
                    "data": {
                        "label": info["doc_type"],
                        "header": header,
                        "detail": detail
                    }
                })
        
        except (ValueError, IndexError):
            nodes.append(create_default_node(nid, info))

    return nodes

# %%
build_nodes(final_df, positions)
# Out:
# [{'id': 'C-0',
#   'type': 'doc_flow',
#   'position': {'x': 0, 'y': 0},
#   'data': {'label': 'Sales Order',
#    'header': {'status': 'Completed',
#     'doc_no': '0000000021',
#     'value': '250000000',
#     'time': '2024-04-23'},
#    'detail': [{'name': 'document_type',
#      'value': 'Sales Order',
#      'id': 'document_type_C-0'},
#     {'name': 'doc_no', 'value': '0000000021', 'id': 'doc_no_C-0'},
#     {'name': 'item', 'value': '10', 'id': 'item_C-0'},
#     {'name': 'preced_doc', 'value': '', 'id': 'preced_doc_C-0'},
#     {'name': 'orig_item', 'value': '0', 'id': 'orig_item_C-0'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_C-0'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_C-0'},
#     {'name': 'ref_value', 'value': '250000000', 'id': 'ref_value_C-0'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_C-0'},
#     {'name': 'created_on', 'value': '2024-04-23', 'id': 'created_on_C-0'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_C-0'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_C-0'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_C-0'},
#     {'name': 'doc_code', 'value': 'C', 'id': 'doc_code_C-0'}]}},
#  {'id': 'J-1',
#   'type': 'doc_flow',
#   'position': {'x': 150, 'y': 0},
#   'data': {'label': 'Outbound Delivery',
#    'header': {'status': 'Completed',
#     'doc_no': '0080000019',
#     'value': 'nan',
#     'time': '2024-04-23'},
#    'detail': [{'name': 'document_type',
#      'value': 'Outbound Delivery',
#      'id': 'document_type_J-1'},
#     {'name': 'doc_no', 'value': '0080000019', 'id': 'doc_no_J-1'},
#     {'name': 'item', 'value': '10', 'id': 'item_J-1'},
#     {'name': 'preced_doc', 'value': '0000000021', 'id': 'preced_doc_J-1'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_J-1'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_J-1'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_J-1'},
#     {'name': 'ref_value', 'value': 'nan', 'id': 'ref_value_J-1'},
#     {'name': 'curr', 'value': 'nan', 'id': 'curr_J-1'},
#     {'name': 'created_on', 'value': '2024-04-23', 'id': 'created_on_J-1'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_J-1'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_J-1'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_J-1'},
#     {'name': 'doc_code', 'value': 'J', 'id': 'doc_code_J-1'}]}},
#  {'id': 'Q-2',
#   'type': 'doc_flow',
#   'position': {'x': 150, 'y': 150},
#   'data': {'label': 'Picking Request',
#    'header': {'status': 'Completed',
#     'doc_no': '20240423',
#     'value': 'nan',
#     'time': '2024-04-23'},
#    'detail': [{'name': 'document_type',
#      'value': 'Picking Request',
#      'id': 'document_type_Q-2'},
#     {'name': 'doc_no', 'value': '20240423', 'id': 'doc_no_Q-2'},
#     {'name': 'item', 'value': '10', 'id': 'item_Q-2'},
#     {'name': 'preced_doc', 'value': '0080000019', 'id': 'preced_doc_Q-2'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_Q-2'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_Q-2'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_Q-2'},
#     {'name': 'ref_value', 'value': 'nan', 'id': 'ref_value_Q-2'},
#     {'name': 'curr', 'value': 'nan', 'id': 'curr_Q-2'},
#     {'name': 'created_on', 'value': '2024-04-23', 'id': 'created_on_Q-2'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_Q-2'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_Q-2'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_Q-2'},
#     {'name': 'doc_code', 'value': 'Q', 'id': 'doc_code_Q-2'}]}},
#  {'id': 'R-3',
#   'type': 'doc_flow',
#   'position': {'x': 150, 'y': 300},
#   'data': {'label': 'GD Goods Issue',
#    'header': {'status': 'Completed',
#     'doc_no': '4900000219',
#     'value': '199095990',
#     'time': '2024-04-23'},
#    'detail': [{'name': 'document_type',
#      'value': 'GD Goods Issue',
#      'id': 'document_type_R-3'},
#     {'name': 'doc_no', 'value': '4900000219', 'id': 'doc_no_R-3'},
#     {'name': 'item', 'value': '1', 'id': 'item_R-3'},
#     {'name': 'preced_doc', 'value': '0080000019', 'id': 'preced_doc_R-3'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_R-3'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_R-3'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_R-3'},
#     {'name': 'ref_value', 'value': '199095990', 'id': 'ref_value_R-3'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_R-3'},
#     {'name': 'created_on', 'value': '2024-04-23', 'id': 'created_on_R-3'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_R-3'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_R-3'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_R-3'},
#     {'name': 'doc_code', 'value': 'R', 'id': 'doc_code_R-3'}]}},
#  {'id': 'M-4',
#   'type': 'doc_flow',
#   'position': {'x': 300, 'y': 300},
#   'data': {'label': 'Invoice',
#    'header': {'status': 'Completed',
#     'doc_no': '0090000024',
#     'value': '2,500,000,00',
#     'time': '2024-04-23'},
#    'detail': [{'name': 'document_type',
#      'value': 'Invoice',
#      'id': 'document_type_M-4'},
#     {'name': 'doc_no', 'value': '0090000024', 'id': 'doc_no_M-4'},
#     {'name': 'item', 'value': '10', 'id': 'item_M-4'},
#     {'name': 'preced_doc', 'value': '0080000019', 'id': 'preced_doc_M-4'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_M-4'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_M-4'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_M-4'},
#     {'name': 'ref_value', 'value': '2,500,000,00', 'id': 'ref_value_M-4'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_M-4'},
#     {'name': 'created_on', 'value': '2024-04-23', 'id': 'created_on_M-4'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_M-4'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_M-4'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_M-4'},
#     {'name': 'doc_code', 'value': 'M', 'id': 'doc_code_M-4'}]}},
#  {'id': 'E-5',
#   'type': 'doc_flow',
#   'position': {'x': 450, 'y': 300},
#   'data': {'label': 'Journal Entry',
#    'header': {'status': 'Cleared',
#     'doc_no': '0090000024',
#     'value': '2,500,000,00',
#     'time': '2024-04-23'},
#    'detail': [{'name': 'document_type',
#      'value': 'Journal Entry',
#      'id': 'document_type_E-5'},
#     {'name': 'doc_no', 'value': '0090000024', 'id': 'doc_no_E-5'},
#     {'name': 'item', 'value': 'nan', 'id': 'item_E-5'},
#     {'name': 'preced_doc', 'value': '0090000024', 'id': 'preced_doc_E-5'},
#     {'name': 'orig_item', 'value': 'nan', 'id': 'orig_item_E-5'},
#     {'name': 'quantity', 'value': 'nan', 'id': 'quantity_E-5'},
#     {'name': 'unit', 'value': 'nan', 'id': 'unit_E-5'},
#     {'name': 'ref_value', 'value': '2,500,000,00', 'id': 'ref_value_E-5'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_E-5'},
#     {'name': 'created_on', 'value': '2024-04-23', 'id': 'created_on_E-5'},
#     {'name': 'material', 'value': 'nan', 'id': 'material_E-5'},
#     {'name': 'description', 'value': 'nan', 'id': 'description_E-5'},
#     {'name': 'status', 'value': 'Cleared', 'id': 'status_E-5'},
#     {'name': 'doc_code', 'value': 'E', 'id': 'doc_code_E-5'}]}},
#  {'id': 'N-6',
#   'type': 'doc_flow',
#   'position': {'x': 300, 'y': 450},
#   'data': {'label': 'Cancel Invoice',
#    'header': {'status': 'Completed',
#     'doc_no': '0090000025',
#     'value': '2,500,000,00',
#     'time': '2024-04-24'},
#    'detail': [{'name': 'document_type',
#      'value': 'Cancel Invoice',
#      'id': 'document_type_N-6'},
#     {'name': 'doc_no', 'value': '0090000025', 'id': 'doc_no_N-6'},
#     {'name': 'item', 'value': '10', 'id': 'item_N-6'},
#     {'name': 'preced_doc', 'value': '', 'id': 'preced_doc_N-6'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_N-6'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_N-6'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_N-6'},
#     {'name': 'ref_value', 'value': '2,500,000,00', 'id': 'ref_value_N-6'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_N-6'},
#     {'name': 'created_on', 'value': '2024-04-24', 'id': 'created_on_N-6'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_N-6'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_N-6'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_N-6'},
#     {'name': 'doc_code', 'value': 'N', 'id': 'doc_code_N-6'}]}},
#  {'id': 'E-7',
#   'type': 'doc_flow',
#   'position': {'x': 450, 'y': 450},
#   'data': {'label': 'Journal Entry',
#    'header': {'status': 'Cleared',
#     'doc_no': '0100000330',
#     'value': '2,500,000,00',
#     'time': '2024-04-24'},
#    'detail': [{'name': 'document_type',
#      'value': 'Journal Entry',
#      'id': 'document_type_E-7'},
#     {'name': 'doc_no', 'value': '0100000330', 'id': 'doc_no_E-7'},
#     {'name': 'item', 'value': 'nan', 'id': 'item_E-7'},
#     {'name': 'preced_doc', 'value': '0090000025', 'id': 'preced_doc_E-7'},
#     {'name': 'orig_item', 'value': 'nan', 'id': 'orig_item_E-7'},
#     {'name': 'quantity', 'value': 'nan', 'id': 'quantity_E-7'},
#     {'name': 'unit', 'value': 'nan', 'id': 'unit_E-7'},
#     {'name': 'ref_value', 'value': '2,500,000,00', 'id': 'ref_value_E-7'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_E-7'},
#     {'name': 'created_on', 'value': '2024-04-24', 'id': 'created_on_E-7'},
#     {'name': 'material', 'value': 'nan', 'id': 'material_E-7'},
#     {'name': 'description', 'value': 'nan', 'id': 'description_E-7'},
#     {'name': 'status', 'value': 'Cleared', 'id': 'status_E-7'},
#     {'name': 'doc_code', 'value': 'E', 'id': 'doc_code_E-7'}]}},
#  {'id': 'h-8',
#   'type': 'doc_flow',
#   'position': {'x': 150, 'y': 600},
#   'data': {'label': 'RE Goods Delivery',
#    'header': {'status': 'Completed',
#     'doc_no': '4900000225',
#     'value': '199095990',
#     'time': '2024-04-24'},
#    'detail': [{'name': 'document_type',
#      'value': 'RE Goods Delivery',
#      'id': 'document_type_h-8'},
#     {'name': 'doc_no', 'value': '4900000225', 'id': 'doc_no_h-8'},
#     {'name': 'item', 'value': '1', 'id': 'item_h-8'},
#     {'name': 'preced_doc', 'value': '0080000019', 'id': 'preced_doc_h-8'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_h-8'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_h-8'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_h-8'},
#     {'name': 'ref_value', 'value': '199095990', 'id': 'ref_value_h-8'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_h-8'},
#     {'name': 'created_on', 'value': '2024-04-24', 'id': 'created_on_h-8'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_h-8'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_h-8'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_h-8'},
#     {'name': 'doc_code', 'value': 'h', 'id': 'doc_code_h-8'}]}},
#  {'id': 'R-9',
#   'type': 'doc_flow',
#   'position': {'x': 150, 'y': 750},
#   'data': {'label': 'GD Goods Issue',
#    'header': {'status': 'Completed',
#     'doc_no': '4900000226',
#     'value': '199095990',
#     'time': '2024-04-24'},
#    'detail': [{'name': 'document_type',
#      'value': 'GD Goods Issue',
#      'id': 'document_type_R-9'},
#     {'name': 'doc_no', 'value': '4900000226', 'id': 'doc_no_R-9'},
#     {'name': 'item', 'value': '1', 'id': 'item_R-9'},
#     {'name': 'preced_doc', 'value': '0080000019', 'id': 'preced_doc_R-9'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_R-9'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_R-9'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_R-9'},
#     {'name': 'ref_value', 'value': '199095990', 'id': 'ref_value_R-9'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_R-9'},
#     {'name': 'created_on', 'value': '2024-04-24', 'id': 'created_on_R-9'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_R-9'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_R-9'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_R-9'},
#     {'name': 'doc_code', 'value': 'R', 'id': 'doc_code_R-9'}]}},
#  {'id': 'M-10',
#   'type': 'doc_flow',
#   'position': {'x': 300, 'y': 750},
#   'data': {'label': 'Invoice',
#    'header': {'status': 'Completed',
#     'doc_no': '0090000026',
#     'value': '2,500,000,00',
#     'time': '2024-04-24'},
#    'detail': [{'name': 'document_type',
#      'value': 'Invoice',
#      'id': 'document_type_M-10'},
#     {'name': 'doc_no', 'value': '0090000026', 'id': 'doc_no_M-10'},
#     {'name': 'item', 'value': '10', 'id': 'item_M-10'},
#     {'name': 'preced_doc', 'value': '0080000019', 'id': 'preced_doc_M-10'},
#     {'name': 'orig_item', 'value': '10', 'id': 'orig_item_M-10'},
#     {'name': 'quantity', 'value': '10', 'id': 'quantity_M-10'},
#     {'name': 'unit', 'value': 'EA', 'id': 'unit_M-10'},
#     {'name': 'ref_value', 'value': '2,500,000,00', 'id': 'ref_value_M-10'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_M-10'},
#     {'name': 'created_on', 'value': '2024-04-24', 'id': 'created_on_M-10'},
#     {'name': 'material', 'value': 'FERT301', 'id': 'material_M-10'},
#     {'name': 'description', 'value': 'KONA', 'id': 'description_M-10'},
#     {'name': 'status', 'value': 'Completed', 'id': 'status_M-10'},
#     {'name': 'doc_code', 'value': 'M', 'id': 'doc_code_M-10'}]}},
#  {'id': 'E-11',
#   'type': 'doc_flow',
#   'position': {'x': 450, 'y': 750},
#   'data': {'label': 'Journal Entry',
#    'header': {'status': 'Not Cleared',
#     'doc_no': '0090000026',
#     'value': '2,500,000,00',
#     'time': '2024-04-24'},
#    'detail': [{'name': 'document_type',
#      'value': 'Journal Entry',
#      'id': 'document_type_E-11'},
#     {'name': 'doc_no', 'value': '0090000026', 'id': 'doc_no_E-11'},
#     {'name': 'item', 'value': 'nan', 'id': 'item_E-11'},
#     {'name': 'preced_doc', 'value': '0090000026', 'id': 'preced_doc_E-11'},
#     {'name': 'orig_item', 'value': 'nan', 'id': 'orig_item_E-11'},
#     {'name': 'quantity', 'value': 'nan', 'id': 'quantity_E-11'},
#     {'name': 'unit', 'value': 'nan', 'id': 'unit_E-11'},
#     {'name': 'ref_value', 'value': '2,500,000,00', 'id': 'ref_value_E-11'},
#     {'name': 'curr', 'value': 'KRW', 'id': 'curr_E-11'},
#     {'name': 'created_on', 'value': '2024-04-24', 'id': 'created_on_E-11'},
#     {'name': 'material', 'value': 'nan', 'id': 'material_E-11'},
#     {'name': 'description', 'value': 'nan', 'id': 'description_E-11'},
#     {'name': 'status', 'value': 'Not Cleared', 'id': 'status_E-11'},
#     {'name': 'doc_code', 'value': 'E', 'id': 'doc_code_E-11'}]}}]

# %% [markdown]
# 조건 filtering

# %%
def get_filtered_document_numbers(conn, schema, doc_type, conditions: list):
    doc_table_info = config.TABLE_MAP[doc_type] 
    doc_column_map = config.COLUMN_MAP[doc_type]
    
    main_table = doc_table_info['table']

    where_clause = []
    params = []

    for cond in conditions:
        alias_name = cond.get("column")
        column_value = cond.get("value")
        db_col_name = doc_column_map.get(alias_name)

        if db_col_name and column_value:
            #picking request는 vbeln, erdat 값이 모두 있어야 추적 가능
            if doc_type == 'Picking Request' and alias_name == 'doc_no':
                try:
                    date_obj = datetime.strptime(column_value, '%Y%m%d')
                    formatted_date = date_obj.strftime('%Y-%m-%d')
                    where_clause.append(sql.SQL("{col}=%s").format(col=sql.Identifier(db_col_name)))
                    params.append(formatted_date)
                except ValueError:
                    print(f"Pikcing Request의 'doc_no'에 유효하지 않은 날짜 형식: {column_value}")
                    return []
            else:
                where_clause.append(sql.SQL("{col}=%s").format(col=sql.Identifier(db_col_name)))
                params.append(column_value)
    
    if not where_clause:
        print("유효한 필터 조건이 없습니다.")
        return []
    
    where_clause = sql.SQL(" AND ").join(where_clause)

    #journal entry - 역추적을 위해 preced_doc가 필요
    if doc_type == 'Journal Entry' and 'preced_doc' in doc_column_map:
        select_col = sql.SQL('BSEG.VBELN')
        from_clause = sql.SQL("{schema}.{table}").format(schema=sql.Identifier(schema), table=sql.Identifier(main_table))
    else:
        select_col = sql.SQL(f"{doc_table_info['table']}.{doc_table_info['doc_col']}")
        from_clause = sql.SQL("{schema}.{table}").format(schema=sql.Identifier(schema), table=sql.Identifier(main_table))

    query = sql.SQL("""
        SELECT DISTINCT {select_col} 
        FROM {from_clause}
        WHERE {where_clause}
    """).format(select_col=select_col, from_clause=from_clause, where_clause=where_clause)
    
    try:
        with conn.cursor() as cur:
            cur.execute(query, tuple(params))
            return [row[0] for row in cur.fetchall()]
    except Exception as e:
        print(f"필터링된 문서 번호 조회 중 오류 발생: {e}")
        return []

# %%
# sales order document filtering
def get_sales_order_list_with_filter(conn, schema, filters: dict = None):
    if not conn:
        return []
    
    if filters and 'doc_type' in filters and 'conditions' in filters and filters['conditions']:
        print(f"필터링 조건 적용: {filters['doc_type']}")

        doc_type = filters['doc_type']
        conditions = filters['conditions']

        filtered_doc_numbers = get_filtered_document_numbers(conn, schema, doc_type, conditions)

        if not filtered_doc_numbers:
            print("조건에 맞는 문서가 없습니다.")
            return []
        
        # VBFA 테이블을 역추적하여 이 문서들과 연결된 Sales Order 찾기
        query = sql.SQL("""
            WITH RECURSIVE document_chain AS (
                        SELECT VBELV AS pre_doc, VBELN AS post_doc, VBTYP_V AS pre_doc_type
                        FROM {schema}.VBFA
                        WHERE VBELN = ANY(%s::text[])
                        
                        UNION ALL

                        SELECT A.VBELV AS pre_doc, A.VBELN AS post_doc, A.VBTYP_V AS pre_doc_type
                        FROM {schema}.VBFA A
                        JOIN document_chain B ON A.VBELN = B.pre_doc
                        
            )
            SELECT DISTINCT pre_doc
            FROM document_chain
            WHERE pre_doc_type = 'C';
        """).format(schema=sql.Identifier(schema))

        try:
            with conn.cursor() as cur:
                cur.execute(query, (list(filtered_doc_numbers),))
                sales_orders = [row[0] for row in cur.fetchall()]
                print(f"역추적된 sales orders: {sales_orders}")
                return sales_orders
        except Exception as e:
            print(f"역추적 쿼리 실행 중 오류 발생: {e}")
            conn.rollback()
            return []
    
    #필터 조건이 없는 경우, 전체 sales order 목록 조회
    else:
        print('전체 sales order 목록 조회 중...')
        query = sql.SQL("""
            SELECT DISTINCT VBELN FROM {schema}.VBAK ORDER BY VBELN ASC;
        """).format(schema=sql.Identifier(schema))

        try:
            with conn.cursor() as cur:
                cur.execute(query)
                sales_orders = [row[0] for row in cur.fetchall()]
                return sales_orders
        except Exception as e:
            print(f"전체 sales order 조회 중 오류 발생: {e}")
            return []

# %%
def get_db_connection2():
    try:
        conn = psycopg.connect(
            dbname='ontology_db',
            user='postgres',
            password='1234',
            host='192.168.1.154',
            port='8004'
        )
        print("데이터베이스에 성공적으로 연결되었습니다.")
        return conn
    except Exception as e:
        print(f"데이터베이스 연결 실패: {e}")
        return None

# %%
conn = get_db_connection()
get_document_flow_path('0000000027', conn)
# Out:
# 데이터베이스에 성공적으로 연결되었습니다.
# 1단계: VBFA 테이블에서 Document Flow 경로를 조회 중입니다... (Sales Order: 0000000027)
# [{'pre_doc_no': '0000000027',
#   'post_doc_no': '0080000025',
#   'pre_doc_type': 'C',
#   'post_doc_type': 'J'},
#  {'pre_doc_no': '0080000025',
#   'post_doc_no': '20250212',
#   'pre_doc_type': 'J',
#   'post_doc_type': 'Q'},
#  {'pre_doc_no': '0080000025',
#   'post_doc_no': '4900000250',
#   'pre_doc_type': 'J',
#   'post_doc_type': 'R'},
#  {'pre_doc_no': '0080000025',
#   'post_doc_no': '0090000029',
#   'pre_doc_type': 'J',
#   'post_doc_type': 'M'}]

# %%
import importlib
importlib.reload(config)
conn = get_db_connection2()
filters={
    "doc_type": "Picking Request", 
    "conditions": [{"column": "doc_no", "value": "20250212"}]
}
schema='mart'
sales_order_list = get_sales_order_list_with_filter(conn, schema, filters)
# Out:
# 데이터베이스에 성공적으로 연결되었습니다.
# 필터링 조건 적용: Picking Request
# 역추적된 sales orders: ['0000000027']

# %%
for sales_order_number in sales_order_list:
    run_documentflow_pipeline(sales_order_number)
# Out:
# 데이터베이스에 성공적으로 연결되었습니다.
# 1단계: VBFA 테이블에서 Document Flow 경로를 조회 중입니다... (Sales Order: 0000000027)
#
# 성공적으로 Document Flow 경로를 조회했습니다.
#    pre_doc_no post_doc_no pre_doc_type post_doc_type
# 0  0000000027  0080000025            C             J
# 1  0080000025    20250212            J             Q
# 2  0080000025  4900000250            J             R
# 3  0080000025  0090000029            J             M
# 2단계: 경로에 따라 후속 문서 상세 데이터 조회 중...
#
# 최종결과:
